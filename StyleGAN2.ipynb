# %% [markdown]
# ## Environment Set Up

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# %cd '/content/drive/My Drive/Research/GAN/StyleGAN2'
# !nvcc test_nvcc.cu -o test_nvcc -run
# Out:
# /content/drive/My Drive/Research/GAN/StyleGAN2
# CPU says hello.
# GPU says hello.

# %% [markdown]
# ## Create StyleGAN2 Dataset From Raw Data

# %%
#!python dataset_tool.py create_from_images datasets/CUB_200_Train data/CUB_200_Train/
#!python dataset_tool.py create_from_images datasets/CUB_200_Test data/CUB_200_Test/
# Out:
# Loading images from "data/CUB_200_Train/"
# Creating dataset "datasets/CUB_200_Train"
# Added 5994 images.

# %%
# !ls datasets/CUB_200_Train/
# !ls datasets/CUB_200_Test/
# Out:
# CUB_200_Train-r02.tfrecords  CUB_200_Train-r06.tfrecords
# CUB_200_Train-r03.tfrecords  CUB_200_Train-r07.tfrecords
# CUB_200_Train-r04.tfrecords  CUB_200_Train-r08.tfrecords
# CUB_200_Train-r05.tfrecords
# CUB_200_Test-r02.tfrecords  CUB_200_Test-r06.tfrecords
# CUB_200_Test-r03.tfrecords  CUB_200_Test-r07.tfrecords
# CUB_200_Test-r04.tfrecords  CUB_200_Test-r08.tfrecords
# CUB_200_Test-r05.tfrecords

# %% [markdown]
# ## Train StyleGAN2

# %%
# !python run_training.py --num-gpus=1 --data-dir=datasets --config=config-f --dataset=CUB_200_Train --total-kimg=10000
# Out:
# Local submit - run_dir: results/00000-stylegan2-CUB_200_Train-1gpu-config-f
# dnnlib: Running training.training_loop.training_loop() on localhost...
# Streaming data using training.dataset.TFRecordDataset...
# tcmalloc: large alloc 4294967296 bytes == 0x8106000 @  0x7ff224b9d001 0x7ff221629765 0x7ff22168dbb0 0x7ff22168fa4f 0x7ff221726048 0x50a635 0x50cd96 0x507d64 0x509042 0x594931 0x549e5f 0x5513d1 0x59fc4e 0x50d356 0x507d64 0x588e5c 0x59fc4e 0x50d356 0x507d64 0x588e5c 0x59fc4e 0x50d356 0x509758 0x50a48d 0x50bfb4 0x509758 0x50a48d 0x50bfb4 0x507d64 0x588e5c 0x59fc4e
# tcmalloc: large alloc 4294967296 bytes == 0x7ff06d2c8000 @  0x7ff224b9b1e7 0x7ff2216295e1 0x7ff22168dc78 0x7ff22168df37 0x7ff221725f28 0x50a635 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x509758 0x50a48d 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
# ...
